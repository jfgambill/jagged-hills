# %%
import pandas as pd, numpy as np, random

# %%
def build_q_dict(states_df):
    '''Constructs a dictionary of Q values for the Q-learner. The dictionary keeps track of
    the rewards earned in a given state after a given action.'''
    import itertools, random
    
    # list of lists of all possible values (integers) each indicator variable can assume
    list_of_values = [list(states_df[col].unique()) for col in states_df.columns]
    
    # Constructs a list of all possible combinations of indicator values, ie all possible states
    state_list = list(itertools.product(*list_of_values))
    
    # Additional layer of the dict to keep track of position, ie does the learner currently own stock
    q_dict = {'long':{}, 'short':{}, None:{None:{None:0}}}
    
    # Initialize the dict with small random values
    for position in ['long','short',None]:
        for state_tuple in state_list:
            if position == None:
                '''If no position, the learner can take any of 3 actions'''
                q_dict[position][state_tuple] = {'buy':random.random()/10000,
                                                 'sell':random.random()/10000,
                                                 None:random.random()/10000}
            elif position == 'long':
                '''If the position is long, can only sell or hold (ie None action)'''
                q_dict[position][state_tuple] = {'sell':random.random()/10000, 
                                                 None:random.random()/10000}
            else:
                '''If the position is short, can only buy or hold short (ie None action)'''
                q_dict[position][state_tuple] = {'buy':random.random()/10000, 
                                                 None:random.random()/10000}
    return q_dict

# %%
class QLearner():
    '''Creates a Q-learning agent to use on stock market data'''
    
    def __init__(self, states_df, price_series, date_col='Date', train_fraction=.8):
        '''states_df: a pandas dataframe where each column is a time series of states to be monitored 
        by the Q-learner. Each state should be an integer value. The df must be indexed by date. 
        
        price_series: A pandas time series of prices. Must be a pandas series indexed by date and 
        correspond to dates in the states_df'''
        
        assert len(states_df) == len(price_series), "Length of price_series and states_df are not equal."        
        
        self.states_df = states_df
        self.price_series = price_series
        self.states_train, self.states_test, self.prices_train, self.prices_test = self.train_test_split()
        # Instantiate with dummy states for parsimony of q_dict
        self.curr_state = (0, 0, 0, 0, 0, 0, 1, 0)
        self.prev_state = (0, 0, 0, 0, 0, 0, 1, 0)
        self.prev_action = None
        self.prev_price = None
        self.position = None
        self.prev_position = None
        self.prev_reward = 0
        self.cum_reward = 0
        self.alpha = 0.7
        self.gamma = 0.7
        self.epsilon = 0.2
        self.max_train_time = len(self.states_train)
        self.max_test_time = len(self.states_test)
        self.q_dict = build_q_dict(states_df)
        self.history = {}
    
    def train_test_split(self, train_fraction=.8):
        states_df = self.states_df
        price_series = self.price_series
        
        assert states_df.index.all() == price_series.index.all(), \
            "All dates in the states_df must match all dates in the price_series"
        
        end_train = int(len(states_df)*train_fraction)
        end_test = len(states_df) - 1
        states_temp, prices_temp = states_df.copy(), price_series.copy()
        states_train, prices_train = states_temp[:end_train], prices_temp[:end_train]
        
        states_temp, prices_temp = states_df.copy(), price_series.copy()
        states_test, prices_test = states_temp[end_train + 1:end_test],prices_temp[end_train + 1:end_test]
        
        self.states_train = states_train
        self.states_test = states_test
        self.prices_train = prices_train
        self.prices_test = prices_test
        
        return self.states_train, self.states_test, self.prices_train, self.prices_test
                    
    def print_attributes(self, print_q_dict=False):
        # For debugging
        print "The current state is {}".format(self.curr_state)
        print "The previous state is {}".format(self.prev_state)
        print "Today's action is {}".format(self.prev_action)
        print "Today's price is {}".format(self.prev_price)
        print "End of day position is {}".format(self.position)
        print "Today's reward is {}".format(self.prev_reward)
        print "Alpha is {}".format(self.alpha)
        print "Gamma is {}".format(self.gamma)
        print "Epsilon is {}".format(self.epsilon)
        
        if print_q_dict:
            print self.q_dict
        
    def update(self, t, train=True):
        '''Updates all the relevant attributes (q_dict, reward, cum_reward, states, position,
        action, prices) of the Q-learner as it progresses through a training or testing 
        time series. Set 'train' to False to test the learned policy on new data. All actions
        are assumed to take place at the market closing price. Set verbose to True if you
        want messages to help debug.'''        
        
        if t==0:
            # Reset these at the start of each training loop
            self.cum_reward = 0
            self.prev_reward = 0
            self.prev_action = None
            self.prev_price = None
            self.position = None
            self.prev_position = None
            self.prev_reward = 0
        
        if train:
            # if training use the values from the training set
            date = self.states_train.index[t]
            price = self.prices_train.iloc[t]
            # Find the state, ie the tuple of indicator variables, at the given time, t
            inputs = self.states_train.iloc[t]
        else:
            #otherwise use values from the test set
            date = self.states_test.index[t]
            price = self.prices_test.iloc[t]
            # Find the state, ie the tuple of indicator variables, at the given time, t
            inputs = self.states_test.iloc[t]      
        
        '''Calculate the reward based on yesterday's position and today's price.
        Do this before taking any action or updating any attributes.'''
        reward = self.calc_reward(t, train)
        
        # Update current state, ie the tuple of indicator variables
        self.curr_state = tuple(inputs.values)
        
        # Take an action
        if train==False or random.random() > self.epsilon/(t + 1):
            # Take the best action if testing or if random number exceeds epsilon
            action = max(self.q_dict[self.position][self.curr_state], 
                         key=self.q_dict[self.position][self.curr_state].get)
        else:
            # if random number does not exceed epsilon, take a random allowable action
            if self.position == None:
                action = random.choice(['buy','sell',None])
            elif self.position == 'long':
                action = random.choice(['sell',None])
            else:
                action = random.choice(['buy',None]) 
                
        # Update the q_dict 
        # Look up the Q value for the prev state and action
        Qsa = self.q_dict[self.prev_position][self.prev_state][self.prev_action]       
        # Compute the Q value for the next (ie the current) state and action
        Qs_prime_a_prime = self.q_dict[self.position][self.curr_state][max(self.q_dict[self.position][self.curr_state])]
        # Update Q value according to modified Bellman equation
        Qsa += self.alpha * (reward + self.gamma * Qs_prime_a_prime -  Qsa)
        # Set the Q value of the previous state equal to the updated Q value
        self.q_dict[self.prev_position][self.prev_state][self.prev_action] = Qsa
        
        # Update prev_position, then update the current position
        self.prev_position = self.position
        # Update positon after taking action and updating Q dict
        self.position = self.update_position(action)           
        
        self.cum_reward += reward
        self.history[date] = {'action':action,'open_position':self.prev_position,
                              'close_position':self.position,'period_return':reward,
                              'cum_return':self.cum_reward}   
        self.prev_reward = reward
        self.prev_action = action
        self.prev_state = self.curr_state        
        self.prev_price = price
                       
        print "QLearner.update(): inputs = {}, open_position = {}, reward = {},\n \
              action = {}, close_position = {}, cumulative reward = {}".format(
              inputs.values, self.prev_position, reward, action, self.position, self.cum_reward)
        self.print_attributes()
        
    def calc_reward(self, t, train):
        '''Method to calculate the reward earned by the Q-learner based on the position
        from the end of the previous day and today's market action'''
        
        prev_price = self.prev_price
        
        # Determine which price series to use and find today's price
        if train:
            price_today = self.prices_train.iloc[t]
        else:
            price_today = self.prices_test.iloc[t]
            
        if prev_price != None:
            # Calculate reward
            diff = price_today - prev_price
            if self.position == 'long':
                reward = diff
            elif self.position == 'short':
                reward = -diff
            else:
                reward = 0
        else:
            # if there is no previous price, there can be no reward
            reward = 0        
        return reward
        
    def update_position(self, action):
        curr_position = self.position
        
        if curr_position == 'long':
            if action == 'sell':
                self.position = None                
            return self.position
                
        elif curr_position == 'short':
            if action == 'buy':
                self.position = None
            return self.position
            
        else:
            if action == 'sell':
                self.position = 'short'                
            elif action == 'buy':
                self.position = 'long'
            return self.position    
            
        
    def train(self, n_trials=1):
        n = 0
        while n < n_trials:
            t = 0
            print "Training trial number {}...".format(n)
            while t < self.max_train_time:
                self.update(t, train=True)        
                t += 1
            tot_hold = self.price_series[self.max_train_time - 1] - self.price_series[0]
            excess_return = self.cum_reward - tot_hold
            print "The excess return is {}".format(excess_return)   
            n += 1
            
    def test(self, n_trials=1, verbose=True):
        '''Method used to test the trained Q-learner on new data.'''
        n = 0
        while n < n_trials:
            t = 0
            print "Testing . . ."
            while t < self.max_test_time:
                self.update(t, train=False)        
                t += 1
            print "End value of index: {}".format(self.price_series[self.max_test_time - 1])
            print "Beginning value of index: {}".format(self.price_series[0])
            tot_hold = self.price_series[self.max_test_time - 1] - self.price_series[0]
            print "The return from buy and hold is {}".format(tot_hold)
            print "The return from the trading strategy is {}".format(self.cum_reward)
            excess_return = self.cum_reward - tot_hold
            print "The excess return is {}".format(excess_return)   
            n += 1 
        if verbose:
            #shrp_mod, shrp_mkt = self.sharpe_ratio()
            
            print "nothing"
            
    def sharpe_ratio(self):
        '''Method to calculate Sharpe Ratio of both the market (aka self.price_series)
        and the trading system. The risk free rate is assumed to be 0.'''
        
        # Sharpe Ratio of the market
        shrp_mkt = self.price_series.mean() / self.price_series.std()
        history = pd.DataFrame(self.history)
        shrp_mod = history['preiod_return'].mean() / history['preiod_return'].std()
        return history

# %%
df = pd.read_csv('market_direction_int.csv')
df['Date'].apply(pd.Timestamp)
df.head()
# Out:
#          Date  BullBearSpread  OneTenDiff  Hi-Lo  Adv-Dec  VIX  PE_Ratio  \
# 0  2006-08-02               0           0      0        0    0         0
# 1  2006-08-03               0           0      0        1    0         0
# 2  2006-08-04               0           0      0        1    0         0
# 3  2006-08-07               0           0      0        0    1         0
# 4  2006-08-08               0           0      0        0    1         0
#
#    OthMktsMinusMA           SP  SP_Minus_MA
# 0               1  1277.410034            0
# 1               1  1280.270020            0
# 2               1  1279.359985            0
# 3               1  1275.770020            0
# 4               1  1271.479980            0

# %%
df.set_index('Date',inplace=True)
states_df = df[['BullBearSpread','OneTenDiff','Hi-Lo','Adv-Dec','VIX','PE_Ratio','OthMktsMinusMA','SP_Minus_MA']]
price_series = df['SP']

# %%
agent = QLearner(states_df, price_series)

agent.train(n_trials = 1)
agent.test()
# Out:
# Training trial number 0...
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 0 0 0 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = 0
# The current state is (0, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1277.410034
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = 0
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1280.27002
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = short, reward = 0.910035,
#                action = None, close_position = short, cumulative reward = 0.910035
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1279.359985
# End of day position is short
# Today's reward is 0.910035
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 0 1 0 1 0], open_position = short, reward = 3.589965,
#                action = buy, close_position = None, cumulative reward = 4.5
# The current state is (0, 0, 0, 0, 1, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 1, 0, 1, 0)
# Today's action is buy
# Today's price is 1275.77002
# End of day position is None
# Today's reward is 3.589965
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 0 1 0 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = 4.5
# The current state is (0, 0, 0, 0, 1, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 1, 0, 1, 0)
# Today's action is None
# Today's price is 1271.47998
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 0 1 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = 4.5
# The current state is (0, 0, 0, 0, 1, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 1, 0, 1, 0)
# Today's action is sell
# Today's price is 1265.949951
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 0 0 0 0 1 0], open_position = short, reward = -5.860108,
#                action = buy, close_position = None, cumulative reward = -1.360108
# The current state is (0, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1271.810059
# End of day position is None
# Today's reward is -5.860108
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 0 0 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -1.360108
# The current state is (0, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1266.73999
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 0 0 0 0 1 0], open_position = short, reward = -1.469971,
#                action = buy, close_position = None, cumulative reward = -2.830079
# The current state is (0, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1268.209961
# End of day position is None
# Today's reward is -1.469971
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 0 0 0 1 0], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -2.830079
# The current state is (0, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1285.579956
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = long, reward = 9.850098,
#                action = sell, close_position = None, cumulative reward = 7.020019
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1295.430054
# End of day position is None
# Today's reward is 9.850098
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 0 0 0 0 1 0], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = 7.020019
# The current state is (0, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1297.47998
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 0 0 0 1 0], open_position = long, reward = 4.820069,
#                action = sell, close_position = None, cumulative reward = 11.840088
# The current state is (0, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 0, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1302.300049
# End of day position is None
# Today's reward is 4.820069
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = 11.840088
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1297.52002
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = short, reward = -1.299926,
#                action = None, close_position = short, cumulative reward = 10.540162
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1298.819946
# End of day position is short
# Today's reward is -1.299926
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = short, reward = 5.829956,
#                action = None, close_position = short, cumulative reward = 16.370118
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1292.98999
# End of day position is short
# Today's reward is 5.829956
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 0 0 0 1 0], open_position = short, reward = -3.070069,
#                action = None, close_position = short, cumulative reward = 13.300049
# The current state is (1, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 0, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1296.060059
# End of day position is short
# Today's reward is -3.070069
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 0 0 0 1 0], open_position = short, reward = 0.970093,
#                action = None, close_position = short, cumulative reward = 14.270142
# The current state is (1, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 0, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1295.089966
# End of day position is short
# Today's reward is 0.970093
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 0 0 0 1 0], open_position = short, reward = -6.690063,
#                action = None, close_position = short, cumulative reward = 7.580079
# The current state is (1, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 0, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1301.780029
# End of day position is short
# Today's reward is -6.690063
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 0 0 0 1 0], open_position = short, reward = -2.5,
#                action = buy, close_position = None, cumulative reward = 5.080079
# The current state is (1, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 0, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1304.280029
# End of day position is None
# Today's reward is -2.5
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = 5.080079
# The current state is (1, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1305.369995
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = short, reward = 1.550049,
#                action = None, close_position = short, cumulative reward = 6.630128
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1303.819946
# End of day position is short
# Today's reward is 1.550049
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = short, reward = -7.190064,
#                action = None, close_position = short, cumulative reward = -0.559936
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1311.01001
# End of day position is short
# Today's reward is -7.190064
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = short, reward = -0.0,
#                action = buy, close_position = None, cumulative reward = -0.559936
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1311.01001
# End of day position is None
# Today's reward is -0.0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -0.559936
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1313.25
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = long, reward = -12.98999,
#                action = None, close_position = long, cumulative reward = -13.549926
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1300.26001
# End of day position is long
# Today's reward is -12.98999
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 0 0 0 1 0], open_position = long, reward = -6.23999,
#                action = sell, close_position = None, cumulative reward = -19.789916
# The current state is (2, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 0, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1294.02002
# End of day position is None
# Today's reward is -6.23999
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 0 0 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -19.789916
# The current state is (2, 0, 0, 0, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 0, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1298.920044
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 0 0 0 0 0], open_position = short, reward = -0.619995,
#                action = None, close_position = short, cumulative reward = -20.409911
# The current state is (2, 0, 0, 0, 0, 0, 0, 0)
# The previous state is (2, 0, 0, 0, 0, 0, 0, 0)
# Today's action is None
# Today's price is 1299.540039
# End of day position is short
# Today's reward is -0.619995
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 0 0], open_position = short, reward = -13.459961,
#                action = None, close_position = short, cumulative reward = -33.869872
# The current state is (2, 0, 0, 1, 0, 0, 0, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 0, 0)
# Today's action is None
# Today's price is 1313.0
# End of day position is short
# Today's reward is -13.459961
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 0 0], open_position = short, reward = -5.069946,
#                action = None, close_position = short, cumulative reward = -38.939818
# The current state is (2, 0, 0, 1, 0, 0, 0, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 0, 0)
# Today's action is None
# Today's price is 1318.069946
# End of day position is short
# Today's reward is -5.069946
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 1 0 0 1 0], open_position = short, reward = 1.789917,
#                action = None, close_position = short, cumulative reward = -37.149901
# The current state is (1, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1316.280029
# End of day position is short
# Today's reward is 1.789917
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 1 0 0 0 0], open_position = short, reward = -3.380005,
#                action = None, close_position = short, cumulative reward = -40.529906
# The current state is (1, 0, 0, 1, 0, 0, 0, 0)
# The previous state is (1, 0, 0, 1, 0, 0, 0, 0)
# Today's action is None
# Today's price is 1319.660034
# End of day position is short
# Today's reward is -3.380005
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 1 0 0 1 0], open_position = short, reward = -1.52002,
#                action = buy, close_position = None, cumulative reward = -42.049926
# The current state is (1, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1321.180054
# End of day position is None
# Today's reward is -1.52002
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -42.049926
# The current state is (1, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1317.640015
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 0 1 0 0 1 0], open_position = short, reward = -7.540039,
#                action = buy, close_position = None, cumulative reward = -49.589965
# The current state is (1, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1325.180054
# End of day position is None
# Today's reward is -7.540039
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -49.589965
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1318.030029
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 0 0 0 0 0], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -49.589965
# The current state is (2, 0, 0, 0, 0, 0, 0, 0)
# The previous state is (2, 0, 0, 0, 0, 0, 0, 0)
# Today's action is buy
# Today's price is 1314.780029
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 0 1 0 0 0 0], open_position = long, reward = 11.589966,
#                action = sell, close_position = None, cumulative reward = -37.999999
# The current state is (2, 0, 0, 1, 0, 0, 0, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 0, 0)
# Today's action is sell
# Today's price is 1326.369995
# End of day position is None
# Today's reward is 11.589966
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 1 0 0 0 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -37.999999
# The current state is (2, 0, 0, 1, 0, 0, 0, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 0, 0)
# Today's action is sell
# Today's price is 1336.349976
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = short, reward = -0.23999,
#                action = buy, close_position = None, cumulative reward = -38.239989
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1336.589966
# End of day position is None
# Today's reward is -0.23999
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -38.239989
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1338.880005
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -38.239989
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1335.849976
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -38.239989
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1335.849976
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -38.239989
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1331.319946
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -38.239989
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is sell
# Today's price is 1334.109985
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 1 0 0 1 0], open_position = short, reward = -16.089966,
#                action = buy, close_position = None, cumulative reward = -54.329955
# The current state is (2, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 0)
# Today's action is buy
# Today's price is 1350.199951
# End of day position is None
# Today's reward is -16.089966
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -54.329955
# The current state is (0, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1353.219971
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = long, reward = -3.630005,
#                action = None, close_position = long, cumulative reward = -57.95996
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1349.589966
# End of day position is long
# Today's reward is -3.630005
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = long, reward = 1.070068,
#                action = None, close_position = long, cumulative reward = -56.889892
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1350.660034
# End of day position is long
# Today's reward is 1.070068
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 0 1 1], open_position = long, reward = 2.76001,
#                action = None, close_position = long, cumulative reward = -54.129882
# The current state is (0, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1353.420044
# End of day position is long
# Today's reward is 2.76001
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 0 1 0], open_position = long, reward = -3.470093,
#                action = None, close_position = long, cumulative reward = -57.599975
# The current state is (0, 0, 0, 1, 0, 0, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 0, 1, 0)
# Today's action is None
# Today's price is 1349.949951
# End of day position is long
# Today's reward is -3.470093
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = long, reward = 12.880005,
#                action = sell, close_position = None, cumulative reward = -44.71997
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1362.829956
# End of day position is None
# Today's reward is 12.880005
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -44.71997
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1365.619995
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -44.71997
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1369.060059
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -44.71997
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1364.050049
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -44.71997
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1365.800049
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = short, reward = -1.159912,
#                action = None, close_position = short, cumulative reward = -45.879882
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1366.959961
# End of day position is short
# Today's reward is -1.159912
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = short, reward = -1.640015,
#                action = None, close_position = short, cumulative reward = -47.519897
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1368.599976
# End of day position is short
# Today's reward is -1.640015
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = short, reward = -8.420044,
#                action = buy, close_position = None, cumulative reward = -55.939941
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1377.02002
# End of day position is None
# Today's reward is -8.420044
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -55.939941
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1377.380005
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -55.939941
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1382.219971
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -55.939941
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1389.079956
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = long, reward = -11.73999,
#                action = None, close_position = long, cumulative reward = -67.679931
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1377.339966
# End of day position is long
# Today's reward is -11.73999
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = long, reward = 0.590088,
#                action = None, close_position = long, cumulative reward = -67.089843
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1377.930054
# End of day position is long
# Today's reward is 0.590088
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = long, reward = 0.00988700000016,
#                action = None, close_position = long, cumulative reward = -67.079956
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1377.939941
# End of day position is long
# Today's reward is 0.00988700000016
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = long, reward = -10.129882,
#                action = None, close_position = long, cumulative reward = -77.209838
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1367.810059
# End of day position is long
# Today's reward is -10.129882
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 1 0 0 1 1], open_position = long, reward = -0.470093,
#                action = None, close_position = long, cumulative reward = -77.679931
# The current state is (1, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1367.339966
# End of day position is long
# Today's reward is -0.470093
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 1 0 0 1 1], open_position = long, reward = -3.039917,
#                action = None, close_position = long, cumulative reward = -80.719848
# The current state is (1, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1364.300049
# End of day position is long
# Today's reward is -3.039917
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 1 0 0 1 1], open_position = long, reward = 15.47998,
#                action = sell, close_position = None, cumulative reward = -65.239868
# The current state is (1, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1379.780029
# End of day position is None
# Today's reward is 15.47998
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -65.239868
# The current state is (1, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1382.839966
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 0 1 0 0 1 1], open_position = short, reward = -2.880005,
#                action = buy, close_position = None, cumulative reward = -68.119873
# The current state is (1, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1385.719971
# End of day position is None
# Today's reward is -2.880005
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.119873
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1378.329956
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.119873
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1380.900024
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.119873
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1384.420044
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 0 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.119873
# The current state is (2, 0, 0, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 0, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1393.219971
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.119873
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1396.569946
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.119873
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1399.76001
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -68.119873
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1401.199951
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = long, reward = -0.699951,
#                action = sell, close_position = None, cumulative reward = -68.819824
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1400.5
# End of day position is None
# Today's reward is -0.699951
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.819824
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1402.810059
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [2 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -68.819824
# The current state is (2, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (2, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1406.089966
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -68.819824
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1406.089966
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = short, reward = 5.140015,
#                action = None, close_position = short, cumulative reward = -63.679809
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1400.949951
# End of day position is short
# Today's reward is 5.140015
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = short, reward = 18.98999,
#                action = None, close_position = short, cumulative reward = -44.689819
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1381.959961
# End of day position is short
# Today's reward is 18.98999
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = short, reward = -4.76001,
#                action = None, close_position = short, cumulative reward = -49.449829
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1386.719971
# End of day position is short
# Today's reward is -4.76001
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = short, reward = -12.760009,
#                action = None, close_position = short, cumulative reward = -62.209838
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1399.47998
# End of day position is short
# Today's reward is -12.760009
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = short, reward = -1.150025,
#                action = None, close_position = short, cumulative reward = -63.359863
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1400.630005
# End of day position is short
# Today's reward is -1.150025
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = short, reward = 3.920044,
#                action = None, close_position = short, cumulative reward = -59.439819
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1396.709961
# End of day position is short
# Today's reward is 3.920044
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = short, reward = -12.410034,
#                action = None, close_position = short, cumulative reward = -71.849853
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1409.119995
# End of day position is short
# Today's reward is -12.410034
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = short, reward = -5.640015,
#                action = buy, close_position = None, cumulative reward = -77.489868
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1414.76001
# End of day position is None
# Today's reward is -5.640015
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -77.489868
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1412.900024
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = short, reward = 5.609985,
#                action = buy, close_position = None, cumulative reward = -71.879883
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1407.290039
# End of day position is None
# Today's reward is 5.609985
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -71.879883
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1409.839966
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = short, reward = -3.200073,
#                action = buy, close_position = None, cumulative reward = -75.079956
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1413.040039
# End of day position is None
# Today's reward is -3.200073
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -75.079956
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1411.560059
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -75.079956
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1413.209961
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -75.079956
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1425.48999
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = long, reward = 1.599976,
#                action = None, close_position = long, cumulative reward = -73.47998
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1427.089966
# End of day position is long
# Today's reward is 1.599976
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = long, reward = -4.609986,
#                action = None, close_position = long, cumulative reward = -78.089966
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1422.47998
# End of day position is long
# Today's reward is -4.609986
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = long, reward = 3.070069,
#                action = sell, close_position = None, cumulative reward = -75.019897
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1425.550049
# End of day position is None
# Today's reward is 3.070069
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -75.019897
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1423.530029
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = long, reward = -5.22998,
#                action = None, close_position = long, cumulative reward = -80.249877
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1418.300049
# End of day position is long
# Today's reward is -5.22998
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = long, reward = -7.540039,
#                action = None, close_position = long, cumulative reward = -87.789916
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1410.76001
# End of day position is long
# Today's reward is -7.540039
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = long, reward = 0.0,
#                action = sell, close_position = None, cumulative reward = -87.789916
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1410.76001
# End of day position is None
# Today's reward is 0.0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -87.789916
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is sell
# Today's price is 1416.900024
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 1 1 0 0 1 1], open_position = short, reward = -9.939942,
#                action = buy, close_position = None, cumulative reward = -97.729858
# The current state is (0, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (0, 0, 1, 1, 0, 0, 1, 1)
# Today's action is buy
# Today's price is 1426.839966
# End of day position is None
# Today's reward is -9.939942
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -97.729858
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1424.72998
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 0 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -97.729858
# The current state is (1, 0, 1, 1, 0, 0, 1, 1)
# The previous state is (1, 0, 1, 1, 0, 0, 1, 1)
# Today's action is None
# Today's price is 1418.300049
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# ...
#                action = None, close_position = None, cumulative reward = -149.858769
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2168.27002
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -149.858769
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2168.27002
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -149.858769
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is buy
# Today's price is 2161.199951
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = long, reward = -10.709961,
#                action = sell, close_position = None, cumulative reward = -160.56873
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is sell
# Today's price is 2150.48999
# End of day position is None
# Today's reward is -10.709961
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -160.56873
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2159.72998
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 0 1 0 2 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -160.56873
# The current state is (1, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 2, 1, 1)
# Today's action is sell
# Today's price is 2160.77002
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 0 1 0 2 1 1], open_position = short, reward = 7.03003,
#                action = buy, close_position = None, cumulative reward = -153.5387
# The current state is (1, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 2, 1, 1)
# Today's action is buy
# Today's price is 2153.73999
# End of day position is None
# Today's reward is 7.03003
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 0 1 0 2 1 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -153.5387
# The current state is (1, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (1, 0, 0, 1, 0, 2, 1, 1)
# Today's action is sell
# Today's price is 2163.659912
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 0 1 1 2 1 1], open_position = short, reward = 26.929932,
#                action = buy, close_position = None, cumulative reward = -126.608768
# The current state is (1, 0, 0, 1, 1, 2, 1, 1)
# The previous state is (1, 0, 0, 1, 1, 2, 1, 1)
# Today's action is buy
# Today's price is 2136.72998
# End of day position is None
# Today's reward is 26.929932
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 0 1 1 2 1 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -126.608768
# The current state is (1, 0, 0, 1, 1, 2, 1, 1)
# The previous state is (1, 0, 0, 1, 1, 2, 1, 1)
# Today's action is None
# Today's price is 2139.179932
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 1 2 1 0], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -126.608768
# The current state is (0, 0, 0, 1, 1, 2, 1, 0)
# The previous state is (0, 0, 0, 1, 1, 2, 1, 0)
# Today's action is buy
# Today's price is 2132.550049
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 0 1 1 2 1 0], open_position = long, reward = 0.429931,
#                action = None, close_position = long, cumulative reward = -126.178837
# The current state is (0, 0, 0, 1, 1, 2, 1, 0)
# The previous state is (0, 0, 0, 1, 1, 2, 1, 0)
# Today's action is None
# Today's price is 2132.97998
# End of day position is long
# Today's reward is 0.429931
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 1 2 1 0], open_position = long, reward = -6.47998,
#                action = None, close_position = long, cumulative reward = -132.658817
# The current state is (0, 0, 0, 1, 1, 2, 1, 0)
# The previous state is (0, 0, 0, 1, 1, 2, 1, 0)
# Today's action is None
# Today's price is 2126.5
# End of day position is long
# Today's reward is -6.47998
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 1 2 1 1], open_position = long, reward = 13.100098,
#                action = None, close_position = long, cumulative reward = -119.558719
# The current state is (0, 0, 0, 1, 1, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 1, 2, 1, 1)
# Today's action is None
# Today's price is 2139.600098
# End of day position is long
# Today's reward is 13.100098
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = long, reward = 4.689941,
#                action = None, close_position = long, cumulative reward = -114.868778
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2144.290039
# End of day position is long
# Today's reward is 4.689941
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = long, reward = -2.949951,
#                action = None, close_position = long, cumulative reward = -117.818729
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2141.340088
# End of day position is long
# Today's reward is -2.949951
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = long, reward = -0.180176,
#                action = None, close_position = long, cumulative reward = -117.998905
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2141.159912
# End of day position is long
# Today's reward is -0.180176
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = long, reward = 10.170166,
#                action = None, close_position = long, cumulative reward = -107.828739
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2151.330078
# End of day position is long
# Today's reward is 10.170166
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 1], open_position = long, reward = -8.170166,
#                action = None, close_position = long, cumulative reward = -115.998905
# The current state is (0, 0, 0, 1, 0, 2, 1, 1)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 1)
# Today's action is None
# Today's price is 2143.159912
# End of day position is long
# Today's reward is -8.170166
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 0 1 0 2 1 0], open_position = long, reward = -3.72998,
#                action = None, close_position = long, cumulative reward = -119.728885
# The current state is (0, 0, 0, 1, 0, 2, 1, 0)
# The previous state is (0, 0, 0, 1, 0, 2, 1, 0)
# Today's action is None
# Today's price is 2139.429932
# End of day position is long
# Today's reward is -3.72998
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 1 2 1 0], open_position = long, reward = -6.389893,
#                action = None, close_position = long, cumulative reward = -126.118778
# The current state is (0, 0, 1, 1, 1, 2, 1, 0)
# The previous state is (0, 0, 1, 1, 1, 2, 1, 0)
# Today's action is None
# Today's price is 2133.040039
# End of day position is long
# Today's reward is -6.389893
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 1 2 1 0], open_position = long, reward = -6.630127,
#                action = None, close_position = long, cumulative reward = -132.748905
# The current state is (0, 0, 1, 1, 1, 2, 1, 0)
# The previous state is (0, 0, 1, 1, 1, 2, 1, 0)
# Today's action is None
# Today's price is 2126.409912
# End of day position is long
# Today's reward is -6.630127
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 1 2 1 0], open_position = long, reward = -0.26001,
#                action = sell, close_position = None, cumulative reward = -133.008915
# The current state is (0, 0, 1, 1, 1, 2, 1, 0)
# The previous state is (0, 0, 1, 1, 1, 2, 1, 0)
# Today's action is sell
# Today's price is 2126.149902
# End of day position is None
# Today's reward is -0.26001
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 1 1 1 2 1 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -133.008915
# The current state is (0, 0, 1, 1, 1, 2, 1, 0)
# The previous state is (0, 0, 1, 1, 1, 2, 1, 0)
# Today's action is None
# Today's price is 2111.719971
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 1 2 0 0], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -133.008915
# The current state is (0, 0, 1, 1, 1, 2, 0, 0)
# The previous state is (0, 0, 1, 1, 1, 2, 0, 0)
# Today's action is buy
# Today's price is 2097.939941
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [0 0 1 1 2 2 0 0], open_position = long, reward = -9.280029,
#                action = None, close_position = long, cumulative reward = -142.288944
# The current state is (0, 0, 1, 1, 2, 2, 0, 0)
# The previous state is (0, 0, 1, 1, 2, 2, 0, 0)
# Today's action is None
# Today's price is 2088.659912
# End of day position is long
# Today's reward is -9.280029
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 2 2 0 0], open_position = long, reward = -3.47998,
#                action = None, close_position = long, cumulative reward = -145.768924
# The current state is (0, 0, 1, 1, 2, 2, 0, 0)
# The previous state is (0, 0, 1, 1, 2, 2, 0, 0)
# Today's action is None
# Today's price is 2085.179932
# End of day position is long
# Today's reward is -3.47998
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 1 2 0 0], open_position = long, reward = 46.340088,
#                action = sell, close_position = None, cumulative reward = -99.428836
# The current state is (0, 0, 1, 1, 1, 2, 0, 0)
# The previous state is (0, 0, 1, 1, 1, 2, 0, 0)
# Today's action is sell
# Today's price is 2131.52002
# End of day position is None
# Today's reward is 46.340088
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [0 0 1 1 1 2 0 0], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -99.428836
# The current state is (0, 0, 1, 1, 1, 2, 0, 0)
# The previous state is (0, 0, 1, 1, 1, 2, 0, 0)
# Today's action is None
# Today's price is 2139.560059
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [0 0 1 1 0 2 0 1], open_position = None, reward = 0,
#                action = buy, close_position = long, cumulative reward = -99.428836
# The current state is (0, 0, 1, 1, 0, 2, 0, 1)
# The previous state is (0, 0, 1, 1, 0, 2, 0, 1)
# Today's action is buy
# Today's price is 2163.26001
# End of day position is long
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: buy
# QLearner.update(): inputs = [1 0 1 1 0 2 0 1], open_position = long, reward = 4.21997,
#                action = None, close_position = long, cumulative reward = -95.208866
# The current state is (1, 0, 1, 1, 0, 2, 0, 1)
# The previous state is (1, 0, 1, 1, 0, 2, 0, 1)
# Today's action is None
# Today's price is 2167.47998
# End of day position is long
# Today's reward is 4.21997
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 2 0 1], open_position = long, reward = -3.030029,
#                action = None, close_position = long, cumulative reward = -98.238895
# The current state is (1, 0, 1, 1, 0, 2, 0, 1)
# The previous state is (1, 0, 1, 1, 0, 2, 0, 1)
# Today's action is None
# Today's price is 2164.449951
# End of day position is long
# Today's reward is -3.030029
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 2 0 1], open_position = long, reward = -0.25,
#                action = sell, close_position = None, cumulative reward = -98.488895
# The current state is (1, 0, 1, 1, 0, 2, 0, 1)
# The previous state is (1, 0, 1, 1, 0, 2, 0, 1)
# Today's action is sell
# Today's price is 2164.199951
# End of day position is None
# Today's reward is -0.25
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: sell
# QLearner.update(): inputs = [1 0 1 1 0 2 0 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -98.488895
# The current state is (1, 0, 1, 1, 0, 2, 0, 1)
# The previous state is (1, 0, 1, 1, 0, 2, 0, 1)
# Today's action is None
# Today's price is 2180.389893
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 2 0 1], open_position = None, reward = 0,
#                action = None, close_position = None, cumulative reward = -98.488895
# The current state is (1, 0, 1, 1, 0, 2, 0, 1)
# The previous state is (1, 0, 1, 1, 0, 2, 0, 1)
# Today's action is None
# Today's price is 2176.939941
# End of day position is None
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# ***The previous action was: None
# QLearner.update(): inputs = [1 0 1 1 0 2 0 1], open_position = None, reward = 0,
#                action = sell, close_position = short, cumulative reward = -98.488895
# The current state is (1, 0, 1, 1, 0, 2, 0, 1)
# The previous state is (1, 0, 1, 1, 0, 2, 0, 1)
# Today's action is sell
# Today's price is 2187.120117
# End of day position is short
# Today's reward is 0
# Alpha is 0.7
# Gamma is 0.7
# Epsilon is 0.2
# End value of index: 1278.599976
# Beginning value of index: 1277.410034
# The return from buy and hold is 1.189942
# The return from the trading strategy is -98.488895
# The excess return is -99.678837
# nothing

# %%
agent.q_dict[None][None]#[self.prev_action]
# Out:
# {None: 0}

# %%
agent.prev_action
# Out:
# 'sell'

# %%
agent.prev_state
# Out:
# (0, 0, 0, 1, 0, 0, 1, 0)
